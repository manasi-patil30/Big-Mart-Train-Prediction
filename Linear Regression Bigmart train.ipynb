# %% [markdown]
# # Linear Regression : PROJECT : BIGMART

# %%
# import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Extract Data 
# 2. EDA 
# 3. Data Cleaning 
# 4. Data Preprocessing 
# 5. Decide I/P and O/P
# 6. Splitting Data 
# 7. Training Model
# 8. Predicting Results
# 9. Evaluate ML Mode

# %%
print(classification_report(Y_test, pred))

# %%
df= pd.read_csv(r"C:\Users\manas\Downloads\bigmart_train.csv")

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Check Null values

df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Checking null values in percentages

np.round(df.isnull().sum() / df.shape[0], 4 ) * 100

# Missing values treatment required.
# Out:
# Item_Identifier               0.00
# Item_Weight                  17.17
# Item_Fat_Content              0.00
# Item_Visibility               0.00
# Item_Type                     0.00
# Item_MRP                      0.00
# Outlet_Identifier             0.00
# Outlet_Establishment_Year     0.00
# Outlet_Size                  28.28
# Outlet_Location_Type          0.00
# Outlet_Type                   0.00
# Item_Outlet_Sales             0.00
# dtype: float64

# %%
#  Identify categorical features.

df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
categorical = ['Item_Fat_Content ','Item_Type''Outlet_Identifier',
       'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type']

# %% [markdown]
# ###  Data Analysis

# %%
# Identify unique values in 'Item_Fat_Content '.

df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
# Display count of each value.

df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
# Replace 'LF' ,'Low Fat' , with 'Low Fat'

# List Comprehension

# List_name =            {var               condition        for loop}
df['Item_Fat_Content'] = ['Low Fat'      if i == 'LF' or i == 'low fat' or i == 'Low Fat' 
                          else 'Regular'     
                          for i in df['Item_Fat_Content']]

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
# Display it

df['Item_Fat_Content'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Item_Fat_Content'>

# %%
# Display total sales for each item in fat content.


df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].sum().round(2)
# Out:
# Item_Fat_Content
# Low Fat    11904094.53
# Regular     6687030.88
# Name: Item_Outlet_Sales, dtype: float64

# %%
df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].sum().round(2).plot.pie()
# Out:
# <Axes: ylabel='Item_Outlet_Sales'>

# %%
# 2. 'Item_Type'

# %%
# Identify all unique values.

df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
# Display count of all items sold and display it.
df['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
df['Item_Type'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Item_Type'>

# %%
# Display sales per item and Display it.

df.groupby('Item_Type')['Item_Outlet_Sales'].sum().round(2)
# Out:
# Item_Type
# Baking Goods             1265525.34
# Breads                    553237.19
# Breakfast                 232298.95
# Canned                   1444151.49
# Dairy                    1522594.05
# Frozen Foods             1825734.79
# Fruits and Vegetables    2820059.82
# Hard Drinks               457793.43
# Health and Hygiene       1045200.14
# Household                2055493.71
# Meat                      917565.61
# Others                    325517.61
# Seafood                   148868.22
# Snack Foods              2732786.09
# Soft Drinks               892897.72
# Starchy Foods             351401.25
# Name: Item_Outlet_Sales, dtype: float64

# %%
df.groupby('Item_Type')['Item_Outlet_Sales'].sum().round(2)  / df['Item_Outlet_Sales'].sum() * 100
# Out:
# Item_Type
# Baking Goods              6.807148
# Breads                    2.975813
# Breakfast                 1.249515
# Canned                    7.767962
# Dairy                     8.189897
# Frozen Foods              9.820464
# Fruits and Vegetables    15.168849
# Hard Drinks               2.462430
# Health and Hygiene        5.622038
# Household                11.056317
# Meat                      4.935503
# Others                    1.750930
# Seafood                   0.800749
# Snack Foods              14.699412
# Soft Drinks               4.802817
# Starchy Foods             1.890156
# Name: Item_Outlet_Sales, dtype: float64

# %%
# 3. 'Outlet_Identifier'

# %%
# Check unique values.

df['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
# Total Sales per Outlet

df.groupby('Outlet_Identifier')['Item_Outlet_Sales'].sum().round(2)
# Out:
# Outlet_Identifier
# OUT010     188340.17
# OUT013    2142663.58
# OUT017    2167465.29
# OUT018    1851822.83
# OUT019     179694.09
# OUT027    3453926.05
# OUT035    2268122.94
# OUT045    2036725.48
# OUT046    2118395.17
# OUT049    2183969.81
# Name: Item_Outlet_Sales, dtype: float64

# %%
df.groupby('Outlet_Identifier')['Item_Outlet_Sales'].sum().round(2).plot.bar()
# Out:
# <Axes: xlabel='Outlet_Identifier'>

# %%
# Outlet sales per Outlet

df.groupby('Outlet_Identifier')['Item_Outlet_Sales'].sum().round(2) /  df['Item_Outlet_Sales'].sum() * 100
# Out:
# Outlet_Identifier
# OUT010     1.013065
# OUT013    11.525196
# OUT017    11.658602
# OUT018     9.960789
# OUT019     0.966558
# OUT027    18.578359
# OUT035    12.200030
# OUT045    10.955364
# OUT046    11.394658
# OUT049    11.747378
# Name: Item_Outlet_Sales, dtype: float64

# %%
# 4.'Outlet_Establishment_Year'

# %%
df['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004], dtype=int64)

# %%
#  Calculate Age of each outlet.   '2024'

df['Age'] = 2024 - df['Outlet_Establishment_Year']

# %%
df['Age']
# Out:
# 0       25
# 1       15
# 2       25
# 3       26
# 4       37
#         ..
# 8518    37
# 8519    22
# 8520    20
# 8521    15
# 8522    27
# Name: Age, Length: 8523, dtype: int64

# %%
# 'Outlet_Size'

# %%
# Unique values

df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
# 'Outlet_Location_Type','Outlet_Type', 'Item_Outlet_Sales'

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: count, dtype: int64

# %%
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %% [markdown]
# ### Missing Value Treatment

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Age                             0
# dtype: int64

# %%
# 1. Numrical : Replace missing values with 'median'
# 2. Categorical : Replace missing values with 'mode'

# %%
# 1. 'Item_Weight'

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].median())       # 12.6

# %%
df['Item_Weight'].value_counts()
# Out:
# Item_Weight
# 12.600    1516
# 12.150      86
# 17.600      82
# 13.650      77
# 11.800      76
#           ...
# 7.275        2
# 7.685        1
# 9.420        1
# 6.520        1
# 5.400        1
# Name: count, Length: 415, dtype: int64

# %%
# 2. 'Outlet_Size'

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna('Medium')

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    5203
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Age                          0
# dtype: int64

# %% [markdown]
# ### Data Pre-processing

# %%
# Categorical  : One hot encoding
# Numerical : Scaling

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_cat = df [['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type','Outlet_Type' ]]
df_num = df[['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Age']]

# %%
df_cat
# Out:
#      Item_Fat_Content Outlet_Size Outlet_Location_Type        Outlet_Type
# 0             Low Fat      Medium               Tier 1  Supermarket Type1
# 1             Regular      Medium               Tier 3  Supermarket Type2
# 2             Low Fat      Medium               Tier 1  Supermarket Type1
# 3             Regular      Medium               Tier 3      Grocery Store
# 4             Low Fat        High               Tier 3  Supermarket Type1
# ...               ...         ...                  ...                ...
# 8518          Low Fat        High               Tier 3  Supermarket Type1
# 8519          Regular      Medium               Tier 2  Supermarket Type1
# 8520          Low Fat       Small               Tier 2  Supermarket Type1
# 8521          Regular      Medium               Tier 3  Supermarket Type2
# 8522          Low Fat       Small               Tier 1  Supermarket Type1
#
# [8523 rows x 4 columns]

# %%
df_num
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Age
# 0           9.300         0.016047  249.8092   25
# 1           5.920         0.019278   48.2692   15
# 2          17.500         0.016760  141.6180   25
# 3          19.200         0.000000  182.0950   26
# 4           8.930         0.000000   53.8614   37
# ...           ...              ...       ...  ...
# 8518        6.865         0.056783  214.5218   37
# 8519        8.380         0.046982  108.1570   22
# 8520       10.600         0.035186   85.1224   20
# 8521        7.210         0.145221  103.1332   15
# 8522       14.800         0.044878   75.4670   27
#
# [8523 rows x 4 columns]

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
# Apply One hot encoding to categorical features.

df_cat_dummies = pd.get_dummies(df_cat)

df_cat_dummies
# Out:
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  Outlet_Size_High  \
# 0                         True                     False             False
# 1                        False                      True             False
# 2                         True                     False             False
# 3                        False                      True             False
# 4                         True                     False              True
# ...                        ...                       ...               ...
# 8518                      True                     False              True
# 8519                     False                      True             False
# 8520                      True                     False             False
# 8521                     False                      True             False
# 8522                      True                     False             False
#
# ...

# %%
# Apply scaling for Numerical features.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MM = MinMaxScaler()

# %%
df_num_mm = MM.fit_transform(df_num)

# %%
df_num_mm = pd.DataFrame(df_num_mm, columns =df_num.columns , index = df_num.index)

# %%
df_num_mm
# Out:
#       Item_Weight  Item_Visibility  Item_MRP       Age
# 0        0.282525         0.048866  0.927507  0.416667
# 1        0.081274         0.058705  0.072068  0.000000
# 2        0.770765         0.051037  0.468288  0.416667
# 3        0.871986         0.000000  0.640093  0.458333
# 4        0.260494         0.000000  0.095805  0.916667
# ...           ...              ...       ...       ...
# 8518     0.137541         0.172914  0.777729  0.916667
# 8519     0.227746         0.143069  0.326263  0.291667
# 8520     0.359929         0.107148  0.228492  0.208333
# 8521     0.158083         0.442219  0.304939  0.000000
# 8522     0.610003         0.136661  0.187510  0.500000
#
# [8523 rows x 4 columns]

# %%
# Concatinate df_cat_dummies and df_num_mm

# %%
final = pd.concat([df_num_mm,df_cat_dummies], axis = 1)

# %%
final
# Out:
#       Item_Weight  Item_Visibility  Item_MRP       Age  \
# 0        0.282525         0.048866  0.927507  0.416667
# 1        0.081274         0.058705  0.072068  0.000000
# 2        0.770765         0.051037  0.468288  0.416667
# 3        0.871986         0.000000  0.640093  0.458333
# 4        0.260494         0.000000  0.095805  0.916667
# ...           ...              ...       ...       ...
# 8518     0.137541         0.172914  0.777729  0.916667
# 8519     0.227746         0.143069  0.326263  0.291667
# 8520     0.359929         0.107148  0.228492  0.208333
# 8521     0.158083         0.442219  0.304939  0.000000
# 8522     0.610003         0.136661  0.187510  0.500000
#
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  Outlet_Size_High  \
# 0                         True                     False             False
# 1                        False                      True             False
# 2                         True                     False             False
# ...

# %%
# 1. Dependant and Indepedant features.
# 2. Split Data
# 3. Train Data
# 4. Predict Outcomes
# 5. Evaluate ML Model

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Age'],
#       dtype='object')

# %%
# 1. Dependent and Independent features

# %%
X = final                       # Input
Y = df['Item_Outlet_Sales']     # Output

# %%
# 2. Split Data  80:20

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.20, random_state= 123)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((6818, 16), (1705, 16), (6818,), (1705,))

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Predict the Outcomes :

# %%
LR_pred = LR.predict(X_test)

# %%
LR_pred [:5].round(2)
# Out:
# array([ 861.42,  788.14, 3062.09, 1813.26, 3959.27])

# %%
Y_test [:5].round(1)
# Out:
# 4532     479.4
# 186      657.8
# 7557     952.1
# 6308     691.1
# 7297    4537.4
# Name: Item_Outlet_Sales, dtype: float64

# %%
#  Evaluate ML Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print("Mean Absolute Error : ", mean_absolute_error(Y_test, LR_pred))
# Out:
# Mean Absolute Error :  831.7475664727614

# %%
print(" MSE : ", mean_squared_error(Y_test, LR_pred))
# Out:
#  MSE :  1237503.1737654635

# %%
r2_score (Y_test, LR_pred)
# Out:
# 0.567734362787049

# %%
LR.coef_
# Out:
# array([   -6.11327092,   -64.64620537,  3687.3584262 ,  -928.42019251,
#          -25.20092861,    25.20092861,   576.73388843,  -332.35527492,
#         -244.37861351,   215.25881928,    13.82026949,  -229.07908877,
#        -1639.2871629 ,  -163.75684498,  -429.25607555,  2232.30008343])

# %%
LR.intercept_
# Out:
# 1276.7551667262824

# %%
# 1. Lasso : (L1 Regularization)
# 2. Ridge : (L2  Regularization)
# 3. ElastiNet (Lasso , Ridge)  (L1, L2)

# %%
# 1. LASSO  [Least Absolute Shrinkage and Selection Operator]

# %%
from sklearn.linear_model import Lasso

# %%
L = Lasso()

# %%
L.fit(X_train, Y_train)
# Out:
# Lasso()

# %%
Lasso_pred  = L.predict(X_test)

# %%
# Evaluate the Model.

# %%
print("MAE :", mean_absolute_error(Y_test,Lasso_pred))
# Out:
# MAE : 832.218706637806

# %%
r2_score(Y_test,Lasso_pred)
# Out:
# 0.5669399134952389

# %%
# 2. Ridge : (L2  Regularization)

# %%
from sklearn.linear_model import Ridge

# %%
R = Ridge()

# %%
R.fit(X_train, Y_train)
# Out:
# Ridge()

# %%
# Predict the Outcomes

Ridge_pred  =R.predict(X_test)

# %%
# Evaluate it

# %%
mean_absolute_error(Y_test,Ridge_pred)
# Out:
# 831.6690282120652

# %%
r2_score(Y_test, Ridge_pred)
# Out:
# 0.5677178651351803

# %%
# 3. ElasticNet (L1, L2 Regularization)

# %%
from sklearn.linear_model import ElasticNet

# %%
EL = ElasticNet()

# %%
EL.fit(X_train, Y_train)
# Out:
# ElasticNet()

# %%
ElasticNet_pred = EL.predict(X_test)

# %%
# Evaluate

# %%
mean_absolute_error(Y_test, ElasticNet_pred)
# Out:
# 1229.537478406018

# %%
r2_score(Y_test, ElasticNet_pred)
# Out:
# 0.17296062680625457
